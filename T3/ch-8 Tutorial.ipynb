# %% [markdown]
# ## Exception handling and OOP (10 marks)

# %% [markdown]
# ## Exception handling
# - syntax error - the code fails to excecute
# - runtime Error - The error is moderetely easy to fix. Exception can be handled
# - Semantic Error - No error in execution; the logic is incorrect(hard to fix)

# %% [markdown]
# ## Syntax Error

# %%
print("hello"
a = 8
print(a)
# Out:
#   File "<ipython-input-2-92bc50503c37>", line 2
#     a = 8
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Runtime Error

# %% [markdown]
# ### NameError

# %%
pritn(Q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4b17cc25c4c8> in <module>
# ----> 1 pritn(Q)
#
# NameError: name 'pritn' is not defined

# %% [markdown]
# ## TypeError

# %%
12 + 'abc'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-23303c9dbde3> in <module>
# ----> 1 12 + 'abc'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
float("one")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8160b2a1e584> in <module>
# ----> 1 float("one")
#
# ValueError: could not convert string to float: 'one'

# %%
l = [1,2,3]
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-9fd344264658> in <module>
#       1 l = [1,2,3]
# ----> 2 l[100]
#
# IndexError: list index out of range

# %% [markdown]
# ## KeyError

# %%
d = {'apple':10,'banana':20}

# %%
d['mango']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7352c047f90b> in <module>
# ----> 1 d['mango']
#
# KeyError: 'mango'

# %% [markdown]
# ## AttributrError

# %%
d.add('mango')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-fe1906b3cc91> in <module>
# ----> 1 d.add('mango')
#
# AttributeError: 'dict' object has no attribute 'add'

# %% [markdown]
# ### IndentationError

# %%
for i in range(3):
print(i)
# Out:
#   File "<ipython-input-11-78291925d94f>", line 2
#     print(i)
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ### StopIteration

# %%
x = (i for i in range(3))

# %%
x
# Out:
# <generator object <genexpr> at 0x00000286869DC9E0>

# %%
next(x)
# Out:
# 0

# %%
next(x)
# Out:
# 1

# %%
next(x)
# Out:
# 2

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-17-92de4e9f6b1e> in <module>
# ----> 1 next(x)
#
# StopIteration:

# %%
import alienmodule
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-67f49f6ac4d9> in <module>
# ----> 1 import alienmodule
#
# ModuleNotFoundError: No module named 'alienmodule'

# %% [markdown]
# ### ZeroDivisionError

# %%
x = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-bfdf2b0f658a> in <module>
# ----> 1 x = 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### ImportError

# %%
from os import strangemodule
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-46b78965462f> in <module>
# ----> 1 from os import strangemodule
#
# ImportError: cannot import name 'strangemodule' from 'os' (C:\ProgramData\Anaconda3\lib\os.py)

# %% [markdown]
# ### FileNotFoundError

# %%
with open("strangefile.txt") as file:
    file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-7fb354fc384d> in <module>
# ----> 1 with  open("strangefile.txt") as file:
#       2     file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'strangefile.txt'

# %% [markdown]
# ### PermissionError

# %%
with open("C://strange.txt",'w') as file:
    file.write("hello")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-23-acb8717a5e9b> in <module>
# ----> 1 with open("C://strange.txt",'w') as file:
#       2     file.write("hello")
#
# PermissionError: [Errno 13] Permission denied: 'C://strange.txt'

# %% [markdown]
# ### RecursionError

# %%
def recursion():
    recursion()

# %%
recursion()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-25-c6e0f7eb0cde> in <module>
# ----> 1 recursion()
#
# <ipython-input-24-d9b9ba688751> in recursion()
#       1 def recursion():
# ----> 2     recursion()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-24-d9b9ba688751> in recursion()
#       1 def recursion():
# ----> 2     recursion()
#
# RecursionError: maximum recursion depth exceeded

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000

# %% [markdown]
# ### OverflowError

# %%
import math
math.factorial(1000)
# Out:
# ...

# %%
10.9**1000
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-30-a03ba401e3b7> in <module>
# ----> 1 10.9**1000
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# ### SystemExit

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### KeyboardInterrupt

# %%
while True:
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a2633aaf53e6> in <module>
#       1 while True:
# ----> 2     print('hi')
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
# ...

# %% [markdown]
# # Exception Handling
#
# #### try except
# **SYNTAX**
# ```PYTHON
# try:
#     statements # this will run first
# except error1:
#     statements # if error1 occurs,this will run
# except error2,error3:
#     statements # if any of error2 , error3 occurs , this will run
# except error4 as var:
#     statements # if error4 occurs it will be assigned to var
# except:
#     statements # in other errors , this will run
# else:
#     statements # it will run if no error occurs
# ```

# %%
try:
    print(Q)
    print("hello world")
except:
    print("good bye")
# Out:
# good bye

# %%
:try:
    print(Q #is not exception it is error
    print("hello world")
except:
    print("good bye")
# Out:
#   File "<ipython-input-38-ad2dae69d21b>", line 1
#     :try:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### `raise keyword`

# %%
x = int(input("Enetr the number : "))
if x < 5:
    raise RuntimeError ("Number less than 5 is not allowed")
# Out:
# Enetr the number : 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-a30889857426> in <module>
#       1 x = int(input("Enetr the number : "))
#       2 if x < 5:
# ----> 3     raise RuntimeError ("Number less than 5 is not allowed")
#
# RuntimeError: Number less than 5 is not allowed

# %% [markdown]
# ### Accessing error and  the message

# %%
try:
    x = 1/0
except Exception as error:
    print("The error is ",type(error))
    print("The error message is ",error)
# Out:
# The error is  <class 'ZeroDivisionError'>
# The error message is  division by zero

# %% [markdown]
# ## try except else finally

# %%
try:
    print("try something here")
except:
    print("This will run if error occurs")
else:
    print("This will eun if it suceeds")
finally:
    print("This will run no matter what")
# Out:
# try something here
# This will eun if it suceeds
# This will run no matter what

# %%
try:
    x = 1/0
    print("try something here")
except:
    print("This will run if error occurs")
else:
    print("This will eun if it suceeds")
finally:
    print("This will run no matter what")
# Out:
# This will run if error occurs
# This will run no matter what

# %% [markdown]
# ## CUSTOM EXCEPTION

# %%
class Myerror(Exception):
    pass
class FiveDivisionError(Myerror):
    pass
try:
    i = int(input("Enter the number"))
    if i==5:
        raise FiveDivisionError
except FiveDivisionError:
    print("Raised custome error")
# Out:
# Enter the number5
# Raised custome error

# %% [markdown]
# ## OBJECT ORIENTED PROGRAMMING IN PYTHON
# - A paradigm in which data and operation are modueled to be intimately paired rather than separate items

# %% [markdown]
# ## Class
# - A bluprint to make object
# ## Object
# - An instance of a class which represents some real world item or concept

# %% [markdown]
# ## Everything in python is object

# %%
a = [1,2,3]
b = 5
c = 'hi'
def hi():
    print("hi")
import math

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(hi))
print(type(math))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'str'>
# <class 'function'>
# <class 'module'>

# %%
print(type(type))
# Out:
# <class 'type'>

# %% [markdown]
# ## An example of OOP in python

# %%
with open("anewfile.txt",'w') as file:
    file.write("hello python")

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## creating class in python

# %%
class person:
    m = "hello"

# %% [markdown]
# ## Create object of the class

# %%
x = person()
y = person()

# %% [markdown]
# ## Class variable

# %%
person.m
# Out:
# 'hello'

# %%
x.m
# Out:
# 'hello'

# %%
y.m
# Out:
# 'hello'

# %%
x.t = 100

# %%
x.t
# Out:
# 100

# %%
y.t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c9b5ada5ed33> in <module>
# ----> 1 y.t
#
# AttributeError: 'person' object has no attribute 't'

# %%
person.t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-74eb7dfd36d0> in <module>
# ----> 1 person.t
#
# AttributeError: type object 'person' has no attribute 't'

# %% [markdown]
# ## Constructor method
# - method that are useful for any kind of instantiation to be performed on objects

# %%
class Mynum:
    def __init__(self):
        print("Calling the init method")
        self.val = 0
    def increment(self):
        self.val += 1
        print(self.val)
    def __str__(self):
        return "This is Mynum object"

# %%
d = Mynum()
# Out:
# Calling the init method

# %%
d.val
# Out:
# 1

# %%
d.increment()
# Out:
# 2

# %%
d.val
# Out:
# 2

# %%
Mynum
# Out:
# __main__.Mynum

# %%
print(d)

# %%
print(d)
# Out:
# This is Mynum object

# %% [markdown]
# ## Destructor method
# - `__del__` dunder method is used to destroy the object. calling this method will delete and garbage collect the object

# %%
class Mynum:
    def __init__(self):
        print("Calling the init method")
        self.val = 0
    def increment(self):
        self.val += 1
        print(self.val)
    def __str__(self):
        return "This is Mynum object"
    def __del__(self):
        print("The del method is called and object destroyed")

# %%
r = Mynum()
# Out:
# Calling the init method

# %%
r

# %%
del r

# %%
r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-d17ca1acc36c> in <module>
# ----> 1 r
#
# NameError: name 'r' is not defined

# %% [markdown]
# ## Another example

# %%
class Employee:
    empcount = 0
    def __init__(self,name,salary):
        self.name = name
        print(id(self.name))
        self.salary = salary
        Employee.empcount += 1
    def displaycount(self):
        print(f"Totle employees are {Employee.empcount}")
    def displayemployee(self):
        print(f"The name is {self.name} and salary is {self.salary}")
    def __str__(self):
        return f"{self.name}"

# %%
emp1 = Employee('python',1000)
# Out:
# 2538195661552

# %%
emp1.displaycount()
# Out:
# Totle employees are 1

# %%
emp1.displayemployee()
# Out:
# The name is python and salary is 1000

# %%
emp2 = Employee("java",2000)
# Out:
# 2538146739568

# %%
emp2.displaycount()
# Out:
# Totle employees are 2

# %%
emp2.displayemployee()
# Out:
# The name is java and salary is 2000

# %%
print(emp1)
# Out:
# python

# %%
emp3 = Employee("C++",3000)
# Out:
# 2538244547440

# %%
print(id(emp3))
# Out:
# 2538248398544

# %%
print(id(emp3.name))
# Out:
# 2538244547440

# %% [markdown]
# # WAP to create a class car. create two objects TATA and MARUTI with name , color and price. For TATA , it is  TATA Altroz , blue and 1000000 price and maruti, it dzire , white and 1000000 price

# %%
class car:
    def __init__(self,name,color,price):
        self.name = name
        self.color = color
        self.price = price
    def displaydetails(self):
        print(f"car name : {self.name}, color : {self.color}, price : {self.price}")
    def __str__(self):
        return f"{self.name}"

# %%
tata = car("TATA Altroz",'blue',1000000)

# %%
tata.displaydetails()
# Out:
# car name : TATA Altroz, color : blue, price : 1000000

# %%
maruti = car("maruti dzire",'White',1000000)

# %%
maruti.displaydetails()
# Out:
# car name : maruti dzire, color : White, price : 1000000

# %% [markdown]
# ## WAP program to demonstrate diffetence between abstraction and ancapsulation

# %%
class diff:
    def __init__(self,a,b):
        self.a = a
        self.b = b
    def add(self):
        return self.a * self.b

# %%
newobject = diff(4,5)

# %%
newobject.add()
# Out:
# 20

# %% [markdown]
# ## 527 Write a Python class named Student with two attributes student_name, marks. Modify the attribute values of the said class and print the original and modified values of the said attributes.

# %%
class student:
    def __init__(self,student_name,marks):
        self.student_name = student_name
        self.marks = marks
    def modify(self):
        self.student_name = 'java'
        self.marks = 90

# %%
p  =student('python',80)

# %%
p.student_name
# Out:
# 'python'

# %%
p.marks
# Out:
# 80

# %%
p.modify()

# %%
p.student_name
# Out:
# 'java'

# %%
p.marks
# Out:
# 90

# %% [markdown]
# ## 528 Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle.

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        return f"The area of ractangle is {self.length * self.width}"

# %%
r = Rectangle(10,5)

# %%
r.area()
# Out:
# 'The area of ractangle is 50'

# %% [markdown]
# ## 529 Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle.

# %%
import math
class Circle:
    def __init__(self,radius):
        self.radius = radius
    def perimeter(self):
        return f"The perimeter of Circle is {2*math.pi*self.radius}"

# %%
Circle(5).perimeter()
# Out:
# 'The perimeter of Circle is 31.41592653589793'

# %% [markdown]
# ## 530 Write a python program to demonstrate the use of try-except-else in Exception handling

# %%
try:
    print(Q)
except:
    print("Error occured")
else:
    print("code run successfully")
# Out:
# Error occured

# %%
def fun():
    try:
        return 1
    except:
        return 2
    finally:
        return 3
fun()
# Out:
# 3

# %% [markdown]
# ## 531 Write a python program to demonstrate the use of raise in Exception handling

# %%
x = int(input("Enter the number"))
if x  <5:
    raise RuntimeError("the number must be greater than 5")
# Out:
# Enter the number3
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-50f0edb387fb> in <module>
#       1 x = int(input("Enter the number"))
#       2 if x  <5:
# ----> 3     raise RuntimeError("the number must be greater than 5")
#
# RuntimeError: the number must be greater than 5

# %% [markdown]
# ## 532 Write a python program to demonstrate the use of custom exceptions in Exception handling.

# %%
class Myerror(Exception):
    pass
class FiveDivisionError(Myerror):
    pass
try:
    i = int(input("Enter the number"))
    if i==5:
        raise FiveDivisionError
except FiveDivisionError:
    print("Raised custome error")
# Out:
# Enter the number5
# Raised custome error

# %% [markdown]
# ## 541
# ```
#  Bank Account class:
#  Create a Python class called BankAccount which represents a bank account,
#  having as attributes: accountNumber (numeric type), name
#  (name of the account owner as string type), balance.
#  Create a constructor with parameters: accountNumber, name, balance.
#  Create a Deposit() method which manages the deposit actions.
#  Create a Withdrawal() method  which manages withdrawals actions.
#  Create a display() method to display account details.
#  Give the complete code for the  BankAccount class.
#  Create the object and call all methods of the  BankAccount  class.
# ```

# %%
class Bankaccount:
    def __init__(self,accountNumber,name,balance):
        self.accountNumber = accountNumber
        self.name = name
        self.balance = balance
    def Deposit(self,deposit):
        self.balance += deposit
        print("your balance after deposit : ",self.balance)
    def Withdrawal(self,withdrow):
        if withdrow < self.balance:
            self.balance -= withdrow
            print("your balance after withdrawal : ",self.balance)
        else:
            print("insuficient balance")
    def display(self):
        print(f"Name : {self.name} , Account Number : {self.accountNumber} , balance : {self.balance}")

# %%
name = input("Enter your name")
accountNumber = input("Enter Account number")
balance = int(input("Enter balance"))
b = Bankaccount(accountNumber,name,balance)
# Out:
# Enter your nameMeet
# Enter Account number123456
# Enter balance5000

# %%
b.display()
# Out:
# Name : Meet , Account Number : 123456 , balance : 5000

# %%
b.Deposit(200)
# Out:
# your balance is :  5200

# %%
b.display()
# Out:
# Name : Meet , Account Number : 123456 , balance : 5200

# %%
b.Withdrawal(5000)
# Out:
# your balance is :  200

# %%
b.display()
# Out:
# Name : Meet , Account Number : 123456 , balance : 200

# %%
b.Withdrawal(1000)
# Out:
# insuficient balance

# %% [markdown]
# # 540 "You need to create a class called Atm. It should have methods to create the pin, to change the pin, to check balance, to withdraw money, to deposit money. Also, you need to create method called menu to choose from the above given operations which you want to perform.
#
# 1. create_pin Method: Ask user to enter the pin to create a new pin. Also ask user to initialize the balance of your account.
#
# 2. change_pin Method: Pin Validation is required before changing the pin. If Pin entered is wrong then message should be displayed “Enter correct pin”. if Pin is correct then update the Old Pin with New Pin.
#
# 3. check_balance Method: Pin Validation is required for checking the balance. It should display the current balance of account.
#
# 4. withdraw Method: Pin Validation is required before withdrawing money. It should ask user for amount to withdraw.  It should also display the insufficient fund message if withdraw amount is higher than balance else balance should be updated after withdraw.
#
# 5. deposit Method: Pin Validation is required before deposit of money. It should ask user for amount to deposit. balance should be updated after deposit.
#
# - After completion of every method it should ask for choice(menu() method) to perform new operation. If you don’t want any operation to perform then you can choose choice of exit to come out from the program
#
# - Bank Account class:
# 1. Create a Python class called BankAccount which represents a bank account,having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.
# 2. Create a constructor with parameters: accountNumber, name, balance.
# 3. Create a Deposit() method which manages the deposit actions.
# 4. Create a Withdrawal() method  which manages withdrawals actions.
# 5. Create a display() method to display account details.
# 6. Give the complete code for the  BankAccount class.
# - Create the object and call all methods of the  BankAccount  class."

# %%
class Atm:
    def __init__(self):
        self.pin = None
        self.balance = 0

    def create_pin(self):
        self.pin = input("Enter new PIN: ")
        self.balance = float(input("Enter initial balance: "))
        print("PIN created successfully and balance initialized.")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter your current PIN: ")
        if old_pin == self.pin:
            new_pin = input("Enter new PIN: ")
            self.pin = new_pin
            print("PIN changed successfully.")
        else:
            print("Enter correct pin.")
        self.menu()

    def check_balance(self):
        entered_pin = input("Enter your PIN: ")
        if entered_pin == self.pin:
            print(f"Your current balance is: {self.balance}")
        else:
            print("Enter correct pin.")
        self.menu()

    def withdraw(self):
        attempt = 0
        while attempt <= 2:
            entered_pin = input("Enter your PIN: ")
            if entered_pin == aAAQA
                amount = float(input("Enter amount to withdraw: "))
                if amount > self.balance:
                    print("Insufficient funds.")
                else:
                    self.balance -= amount
                    print(f"Withdrawal successful. Remaining balance: {self.balance}")
                    break
                self.menu()
            else:
                print("Enter correct pin.")
                attempt += 1
        if attempt == 2:
            print("your account is blocked")
        

    def deposit(self):
        entered_pin = input("Enter your PIN: ")
        if entered_pin == self.pin:
            amount = float(input("Enter amount to deposit: "))
            self.balance += amount
            print(f"Deposit successful. Updated balance: {self.balance}")
        else:
            print("Enter correct pin.")
        self.menu()

    def menu(self):
        print("\nChoose an operation:")
        print("1. Create PIN")
        print("2. Change PIN")
        print("3. Check Balance")
        print("4. Withdraw Money")
        print("5. Deposit Money")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            self.create_pin()
        elif choice == "2":
            self.change_pin()
        elif choice == "3":
            self.check_balance()
        elif choice == "4":
            self.withdraw()
        elif choice == "5":
            self.deposit()
        elif choice == "6":
            print("Thank you for using ATM. Goodbye!")
        else:
            print("Invalid choice. Try again.")
            self.menu()

# %%
# Create object
account = Bankaccount(12345, "John Doe", 5000)

# Call methods
account.display()
account.Deposit(1500)
account.Withdrawal(2000)
account.display()
# Out:
# Name : John Doe , Account Number : 12345 , balance : 5000
# your balance after deposit :  6500
# your balance after withdrawal :  4500
# Name : John Doe , Account Number : 12345 , balance : 4500

# %%
Atm().menu()
# Out:
# Choose an operation:
# 1. Create PIN
# 2. Change PIN
# 3. Check Balance
# 4. Withdraw Money
# 5. Deposit Money
# 6. Exit
# Enter your choice: 1
# Enter new PIN: 1111
# Enter initial balance: 3000
# PIN created successfully and balance initialized.
#
# Choose an operation:
# 1. Create PIN
# 2. Change PIN
# 3. Check Balance
# 4. Withdraw Money
# 5. Deposit Money
# 6. Exit
# Enter your choice: 4
# Enter your PIN: 1111
# Enter amount to withdraw: 1000
# Withdrawal successful. Remaining balance: 2000.0
#
# Choose an operation:
# 1. Create PIN
# 2. Change PIN
# 3. Check Balance
# 4. Withdraw Money
# 5. Deposit Money
# 6. Exit
# Enter your choice: 6
# Thank you for using ATM. Goodbye!

# %% [markdown]
# # 539	Stacks and Queues. Write a class SQ that defines a data structure that can behave as both a queue (FIFO) or a stack (LIFO), There are five methods that should be implemented:
#
# 1. make a constructor with a valid parameter
# 2. shift() returns the first element and removes it from the list. Also, use the custom(raise) exception in this method.
# 3. unshift() "pushes" a new element to the front or head of the list
# 4. push() adds a new element to the end of a list
# 5. pop() returns the last element and removes it from the list
# 6. remove() returns the maximum element of the list and removes it from the list.
# 7. Create the object and call all methods of the SQ class.
